# %%
import pandas as pd

# %%
produtos = pd.read_csv("../data/produtos.csv", sep=";")
produtos
# Out:
#                     IdProduto     DescNomeProduto  \
# 0          001 - Espada Longa        Espada Longa
# 1          002 - Espada Curta        Espada Curta
# 2     003 - Armadura de Couro   Armadura de Couro
# 3    004 - Armadura de Placas  Armadura de Placas
# 4    005 - Botas de Agilidade  Botas de Agilidade
# ..                        ...                 ...
# 113                         5         ChatMessage
# 114                         6          Churn_10pp
# 115                         7           Churn_2pp
# 116                         8           Churn_5pp
# 117                         9           Coca Cola
#
#                      DescDescricaoProduto DescCategoriaProduto
# 0                Uma espada longa de aço.               espada
# 1                   Espada leve e rápida.               espada
# 2           Armadura leve feita de couro.             armadura
# 3    Armadura pesada de placas metálicas.             armadura
# ...

# %%
produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IdProduto             118 non-null    object
#  1   DescNomeProduto       118 non-null    object
#  2   DescDescricaoProduto  77 non-null     object
#  3   DescCategoriaProduto  118 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
produtos.dropna()
# Out:
#                     IdProduto      DescNomeProduto  \
# 0          001 - Espada Longa         Espada Longa
# 1          002 - Espada Curta         Espada Curta
# 2     003 - Armadura de Couro    Armadura de Couro
# 3    004 - Armadura de Placas   Armadura de Placas
# 4    005 - Botas de Agilidade   Botas de Agilidade
# ..                        ...                  ...
# 72        073 - Adaga de Gelo        Adaga de Gelo
# 73     074 - Adaga do Eclipse     Adaga do Eclipse
# 74   075 - Adaga do Relâmpago   Adaga do Relâmpago
# 75      076 - Adaga do Cosmos      Adaga do Cosmos
# 76  077 - Adaga do Apocalipse  Adaga do Apocalipse
#
#                                DescDescricaoProduto DescCategoriaProduto
# 0                          Uma espada longa de aço.               espada
# 1                             Espada leve e rápida.               espada
# 2                     Armadura leve feita de couro.             armadura
# ...

# %%
produtos.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IdProduto             77 non-null     object
#  1   DescNomeProduto       77 non-null     object
#  2   DescDescricaoProduto  77 non-null     object
#  3   DescCategoriaProduto  77 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IdProduto             118 non-null    object
#  1   DescNomeProduto       118 non-null    object
#  2   DescDescricaoProduto  77 non-null     object
#  3   DescCategoriaProduto  118 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
produtos.dropna(how="any")
# Out:
#                     IdProduto      DescNomeProduto  \
# 0          001 - Espada Longa         Espada Longa
# 1          002 - Espada Curta         Espada Curta
# 2     003 - Armadura de Couro    Armadura de Couro
# 3    004 - Armadura de Placas   Armadura de Placas
# 4    005 - Botas de Agilidade   Botas de Agilidade
# ..                        ...                  ...
# 72        073 - Adaga de Gelo        Adaga de Gelo
# 73     074 - Adaga do Eclipse     Adaga do Eclipse
# 74   075 - Adaga do Relâmpago   Adaga do Relâmpago
# 75      076 - Adaga do Cosmos      Adaga do Cosmos
# 76  077 - Adaga do Apocalipse  Adaga do Apocalipse
#
#                                DescDescricaoProduto DescCategoriaProduto
# 0                          Uma espada longa de aço.               espada
# 1                             Espada leve e rápida.               espada
# 2                     Armadura leve feita de couro.             armadura
# ...

# %%
df = pd.DataFrame(
    {
        "nome": ["Jailton", None, "Carol", "Luisa", "Arthur"],
        "idade": [27, None, None, 2, 9],
        "salario": [2500, 1500, 2600, None, None]
    }
)
df
# Out:
#       nome  idade  salario
# 0  Jailton   27.0   2500.0
# 1     None    NaN   1500.0
# 2    Carol    NaN   2600.0
# 3    Luisa    2.0      NaN
# 4   Arthur    9.0      NaN

# %%
df.dropna(how="all")
# Out:
#       nome  idade  salario
# 0  Jailton   27.0   2500.0
# 1     None    NaN   1500.0
# 2    Carol    NaN   2600.0
# 3    Luisa    2.0      NaN
# 4   Arthur    9.0      NaN

# %%
df.dropna(how="any",subset=["idade", "nome"])
# Out:
#       nome  idade  salario
# 0  Jailton   27.0   2500.0
# 3    Luisa    2.0      NaN
# 4   Arthur    9.0      NaN

# %%
medias = df[["idade", "salario"]].mean()

# %%
df["idade"].fillna(0)
# Out:
# 0    27.0
# 1     0.0
# 2     0.0
# 3     2.0
# 4     9.0
# Name: idade, dtype: float64

# %%
df.fillna({"nome": "alguem", "idade": 0})
# Out:
#       nome  idade  salario
# 0  Jailton   27.0   2500.0
# 1   alguem    0.0   1500.0
# 2    Carol    0.0   2600.0
# 3    Luisa    2.0      NaN
# 4   Arthur    9.0      NaN

# %%
df.fillna(medias)
# Out:
#       nome      idade  salario
# 0  Jailton  27.000000   2500.0
# 1     None  12.666667   1500.0
# 2    Carol  12.666667   2600.0
# 3    Luisa   2.000000   2200.0
# 4   Arthur   9.000000   2200.0

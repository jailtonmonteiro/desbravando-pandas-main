# %%
import pandas as pd

# %%
idades = [32, 38, 30, 30, 31, 35, 25, 29, 31, 37, 27, 23, 36, 33, 39]

# %%
series_idades = pd.Series(idades)
series_idades
# Out:
# 0     32
# 1     38
# 2     30
# 3     30
# 4     31
# 5     35
# 6     25
# 7     29
# 8     31
# 9     37
# 10    27
# 11    23
# 12    36
# 13    33
# 14    39
# dtype: int64

# %%
idades[0]
# Out:
# 32

# %%
series_idades = series_idades.sort_values()

# %%
series_idades.iloc[0]
# Out:
# np.int64(23)

# %%
idades = [32, 38, 30, 30, 31, 35, 25, 29, 31, 37, 27, 23, 36, 33, 39]

# %%
indexs = ["Téo", "Maria", "João", "Ana", "Lucas", "Paula", "Pedro", "Lúcia", "Rafael", "Clara", "Bruno", "Sofia", "Miguel", "Laura", "Carol"]

# %%
len(indexs)
# Out:
# 15

# %%
series_idades = pd.Series(idades, index=indexs)
series_idades
# Out:
# Téo       32
# Maria     38
# João      30
# Ana       30
# Lucas     31
# Paula     35
# Pedro     25
# Lúcia     29
# Rafael    31
# Clara     37
# Bruno     27
# Sofia     23
# Miguel    36
# Laura     33
# Carol     39
# dtype: int64

# %%
series_idades['Maria']
# Out:
# np.int64(38)

# %%
series_idades.iloc[3]
# Out:
# np.int64(30)

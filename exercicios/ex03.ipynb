# %%
import pandas as pd

# %%
clientes = pd.read_csv("../data/clientes.csv", sep=";")
transacoes = pd.read_csv("../data/transacoes.csv", sep=";")
produtos = pd.read_csv("../data/produtos.csv", sep=";")

# %%
# Quantas linhas há no arquivo clientes.csv ?
linhas = len(clientes.index)
linhas
# Out:
# 4859

# %%
# Quantas colunas do tipo int há no arquivo transacoes.csv ?
colunas = len(transacoes.select_dtypes(include="int64").columns)
colunas
# Out:
# 1

# %%
# Quantas colunas do tipo object há no arquivo produtos.csv ?
colunas = len(produtos.select_dtypes(include="object").columns)
colunas
# Out:
# C:\Users\jailtonsilva\AppData\Local\Temp\ipykernel_14844\4087875844.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   colunas = len(produtos.select_dtypes(include="object").columns)
# 4

# %%
# Qual o id do cliente no índice 4 no arquivo clientes.csv ?
id = clientes.iloc[4].idCliente
id
# Out:
# '0028dda2-334f-40bb-9582-475fb6719471'

# %%
# Qual o saldo de pontos do cliente na 10a posição (sem ordenar) do arquivo clientes.csv ?
saldo = clientes.iloc[10].qtdePontos
saldo
# Out:
# np.int64(0)

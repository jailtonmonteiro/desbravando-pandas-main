# %%
import pandas as pd

# %%
url = "https://pt.wikipedia.org/wiki/Unidades_federativas_do_Brasil"

# %%
dfs = pd.read_html(url, storage_options={"User-Agent": "Mozilla/5.0"})
uf = dfs[1]
uf
# Out:
#     Bandeira   Unidade federativa Abreviação Sede de governo   Área (km²)  \
# 0        NaN                 Acre         AC      Rio Branco    164 122,2
# 1        NaN              Alagoas         AL          Maceió     27 767,7
# 2        NaN                Amapá         AP          Macapá    142 814,6
# 3        NaN             Amazonas         AM          Manaus  1 570 745,7
# 4        NaN                Bahia         BA        Salvador    564 692,7
# 5        NaN                Ceará         CE       Fortaleza    148 825,6
# 6        NaN     Distrito Federal         DF        Brasília      5 822,1
# 7        NaN       Espírito Santo         ES         Vitória     46 077,5
# 8        NaN                Goiás         GO         Goiânia    340 086,7
# 9        NaN             Maranhão         MA        São Luís    331 983,3
# 10       NaN          Mato Grosso         MT          Cuiabá    903 357,9
# 11       NaN   Mato Grosso do Sul         MS    Campo Grande    357 125,0
# ...

# %%
def str_to_float(x: str):
    return float(x.strip()
                .replace(",", ".")
                .replace(" ", "")
                .replace("\xa0", "")
    )

# %%
colunas = ["Área (km²)", "População (Censo 2022)", "PIB (2015)", "PIB per capita (R$) (2015)"]

# %%
uf["Área (km²)"] = uf["Área (km²)"].apply(str_to_float)
uf["População (Censo 2022)"] = uf["População (Censo 2022)"].apply(str_to_float)
uf["PIB (2015)"] = uf["PIB (2015)"].apply(str_to_float)
uf["PIB per capita (R$) (2015)"] = uf["PIB per capita (R$) (2015)"].apply(str_to_float)
uf.head()
# Out:
#    Bandeira Unidade federativa Abreviação Sede de governo  Área (km²)  \
# 0       NaN               Acre         AC      Rio Branco    164122.2
# 1       NaN            Alagoas         AL          Maceió     27767.7
# 2       NaN              Amapá         AP          Macapá    142814.6
# 3       NaN           Amazonas         AM          Manaus   1570745.7
# 4       NaN              Bahia         BA        Salvador    564692.7
#
#    População (Censo 2022)  Densidade (2005)   PIB (2015)  (% total) (2015)  \
# 0                830018.0               430   13622000.0                 2
# 1               3127683.0             10861   46364000.0                 8
# 2                733759.0               416   13861000.0                 2
# 3               3941613.0               205   86560000.0                14
# 4              14141626.0              2446  245025000.0                41
#
#    PIB per capita (R$) (2015)  IDH (2010) Alfabetização (2016)  \
# ...

# %%
uf.dtypes
# Out:
# Bandeira                       float64
# Unidade federativa                 str
# Abreviação                         str
# Sede de governo                    str
# Área (km²)                     float64
# População (Censo 2022)         float64
# Densidade (2005)                 int64
# PIB (2015)                     float64
# (% total) (2015)                 int64
# PIB per capita (R$) (2015)     float64
# IDH (2010)                       int64
# Alfabetização (2016)               str
# Mortalidade infantil (2016)        str
# Expectativa de vida (2016)         str
# dtype: object

# %%
def expec_vida(x: str):
    return (float(x.split(" ")[0]
                .replace(",",".")
        ))

# %%
uf["Expectativa de vida (2016)"] = uf["Expectativa de vida (2016)"].apply(expec_vida)
uf.head()
# Out:
#    Bandeira Unidade federativa Abreviação Sede de governo  Área (km²)  \
# 0       NaN               Acre         AC      Rio Branco    164122.2
# 1       NaN            Alagoas         AL          Maceió     27767.7
# 2       NaN              Amapá         AP          Macapá    142814.6
# 3       NaN           Amazonas         AM          Manaus   1570745.7
# 4       NaN              Bahia         BA        Salvador    564692.7
#
#    População (Censo 2022)  Densidade (2005)   PIB (2015)  (% total) (2015)  \
# 0                830018.0               430   13622000.0                 2
# 1               3127683.0             10861   46364000.0                 8
# 2                733759.0               416   13861000.0                 2
# 3               3941613.0               205   86560000.0                14
# 4              14141626.0              2446  245025000.0                41
#
#    PIB per capita (R$) (2015)  IDH (2010) Alfabetização (2016)  \
# ...

# %%
# Alfabetização (2016) por cem
# Mortalidade infantil (2016) por mil
